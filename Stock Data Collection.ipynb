# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf

# %%
tech_layoffs = pd.read_csv(r"C:\Users\Nahye\OneDrive - University of Toronto\Documents\Project\Tech Layoff 2\PowerBI Final Data.csv")
tech_layoffs
# Out:
#          #  % Laid Off        Company  Company Size After  \
# 0        1        40.0  Tamara Mellon                30.0
# 1        2        10.0   HopSkipDrive                72.0
# 2        3        75.0    Panda Squad                 2.0
# 3        4       100.0       Help.com                 0.0
# 4        5        22.0      Inspirato               461.0
# ...    ...         ...            ...                 ...
# 1767  1835         NaN   Moxion Power                 NaN
# 1768  1836         5.0         Perion               665.0
# 1769  1837        17.0         Planet               879.0
# 1770  1838         4.0       RealPage               480.0
# 1771  1839        17.0      Priceline               503.0
#
#       Company Size Before      Continent Country  Year Quarter  Month  Day  \
# 0                    50.0  North America     USA  2020   Qtr 1  March   12
# 1                    80.0  North America     USA  2020   Qtr 1  March   13
# ...

# %%
tickers = ['AMZN', 'MSFT', 'META', 'JNJ', 'BRK-B', 'INTU']
start_date = "2020-01-01"
end_date = "2025-01-11"

stock_data_list = []

# %%
for ticker in tickers:
    print(f"Downloading data for {ticker}...")
    data = yf.download(ticker, start=start_date, end=end_date)
    stock_data_list.append(data)
    file_name = f"{ticker}_stock.csv"
    data.to_csv(file_name)
    print(f"Stock data saved as {file_name}")
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Stock data saved as AMZN_stock.csv
# ...
# Stock data saved as MSFT_stock.csv
# ...
# [*********************100%***********************]  1 of 1 completed
# Stock data saved as META_stock.csv
# ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Stock data saved as JNJ_stock.csv
# ...
# Stock data saved as BRK-B_stock.csv
# ...
# [*********************100%***********************]  1 of 1 completed
# Stock data saved as INTU_stock.csv
